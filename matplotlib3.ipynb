# %% [markdown]
# # Histogram Chart

# %%
from matplotlib import pyplot as plt #or (import matplotlib.pyplot as plt )

# %%
import numpy as np
import random

x=np.random.randint(10,60,(50))
x
# Out:
# array([19, 44, 31, 39, 47, 43, 18, 51, 45, 23, 18, 33, 10, 32, 58, 28, 30,
#        42, 27, 16, 52, 59, 37, 53, 21, 49, 48, 11, 20, 56, 55, 46, 22, 53,
#        51, 13, 18, 39, 17, 49, 32, 18, 29, 41, 26, 11, 29, 55, 50, 25])

# %%
no=[19, 44, 31, 39, 47, 43, 18, 51, 45, 23, 18, 33, 10, 32, 58, 28, 30,
       42, 27, 16, 52, 59, 37, 53, 21, 49, 48, 11, 20, 56, 55, 46, 22, 53,
       51, 13, 18, 39, 17, 49, 32, 18, 29, 41, 26, 11, 29, 55, 50, 25]

plt.xlabel("Python")# to give x label
plt.ylabel("No")# to give y label
plt.title('Vishwa') # to give title to chart

plt.hist(no)
plt.show()

# %%
no=[19, 44, 31, 39, 47, 43, 18, 51, 45, 23, 18, 33, 10, 32, 58, 28, 30,
       42, 27, 16, 52, 59, 37, 53, 21, 49, 48, 11, 20, 56, 55, 46, 22, 53,
       51, 13, 18, 39, 17, 49, 32, 18, 29, 41, 26, 11, 29, 55, 50, 25]

plt.hist(no,color='g',edgecolor='b')#to give color


plt.xlabel("Python")# to give x label
plt.ylabel("No")# to give y label
plt.title('Vishwa') # to give title to chart
plt.show()

# %%
no=[19, 44, 31, 39, 47, 43, 18, 51, 45, 23, 18, 33, 10, 32, 58, 28, 30,
       42, 27, 16, 52, 59, 37, 53, 21, 49, 48, 11, 20, 56, 55, 46, 22, 53,
       51, 13, 18, 39, 17, 49, 32, 18, 29, 41, 26, 11, 29, 55, 50, 25]
l=[10,20,30,40,50,60]

plt.hist(no,color='g',edgecolor='b',bins=l)#bins is to give one bar between data before that there are two diff bars


plt.xlabel("Python")
plt.ylabel("No")
plt.title('Vishwa') 
plt.show()

# %%
no=[19, 44, 31, 39, 47, 43, 18, 51, 45, 23, 18, 33, 10, 32, 58, 28, 30,
       42, 27, 16, 52, 59, 37, 53, 21, 49, 48, 11, 20, 56, 55, 46, 22, 53,
       51, 13, 18, 39, 17, 49, 32, 18, 29, 41, 26, 11, 29, 55, 50, 25]
l=[10,20,30,40,50,60]

plt.hist(no,"auto",(0,100),edgecolor='b',color='g') #to give range (0,100)from where to where we want to see x axis

plt.xlabel("Python")
plt.ylabel("No")
plt.title('Vishwa') 
plt.show()

# %%
no=[19, 44, 31, 39, 47, 43, 18, 51, 45, 23, 18, 33, 10, 32, 58, 28, 30,
       42, 27, 16, 52, 59, 37, 53, 21, 49, 48, 11, 20, 56, 55, 46, 22, 53,
       51, 13, 18, 39, 17, 49, 32, 18, 29, 41, 26, 11, 29, 55, 50, 25]
l=[10,20,30,40,50,60]

plt.hist(no,color='g',edgecolor='b',cumulative=-1) #to reverse  frequncy parameter use cumulative=-1


plt.xlabel("Python")
plt.ylabel("No")
plt.title('Vishwa') 
plt.show()

# %%
no=[19, 44, 31, 39, 47, 43, 18, 51, 45, 23, 18, 33, 10, 32, 58, 28, 30,
       42, 27, 16, 52, 59, 37, 53, 21, 49, 48, 11, 20, 56, 55, 46, 22, 53,
       51, 13, 18, 39, 17, 49, 32, 18, 29, 41, 26, 11, 29, 55, 50, 25]
l=[10,20,30,40,50,60]

plt.hist(no,color='g',edgecolor='b',bottom=20,align='mid') #to start y axis with specific number  use bottom=20 #align='mid' is to see where you want to see x axis name middle,left,right


plt.xlabel("Python")
plt.ylabel("No")
plt.title('Vishwa') 
plt.show()

# %%
no=[19, 44, 31, 39, 47, 43, 18, 51, 45, 23, 18, 33, 10, 32, 58, 28, 30,
       42, 27, 16, 52, 59, 37, 53, 21, 49, 48, 11, 20, 56, 55, 46, 22, 53,
       51, 13, 18, 39, 17, 49, 32, 18, 29, 41, 26, 11, 29, 55, 50, 25]
l=[10,20,30,40,50,60]

plt.hist(no,color='g',edgecolor='b',bottom=20,histtype="step") #histtype="step" to change histogram type #(histtype=stepfilled, barstacked,bar,step)


plt.xlabel("Python")
plt.ylabel("No")
plt.title('Vishwa') 
plt.show()

# %%
no=[19, 44, 31, 39, 47, 43, 18, 51, 45, 23, 18, 33, 10, 32, 58, 28, 30,
       42, 27, 16, 52, 59, 37, 53, 21, 49, 48, 11, 20, 56, 55, 46, 22, 53,
       51, 13, 18, 39, 17, 49, 32, 18, 29, 41, 26, 11, 29, 55, 50, 25]
l=[10,20,30,40,50,60]

plt.hist(no,color='g',edgecolor='b',bottom=20,histtype="step",orientation="horizontal")  #orientation="horizontal" to see bar horizontal


plt.xlabel("Python")
plt.ylabel("No")
plt.title('Vishwa') 
plt.show()

# %%
no=[19, 44, 31, 39, 47, 43, 18, 51, 45, 23, 18, 33, 10, 32, 58, 28, 30,
       42, 27, 16, 52, 59, 37, 53, 21, 49, 48, 11, 20, 56, 55, 46, 22, 53,
       51, 13, 18, 39, 17, 49, 32, 18, 29, 41, 26, 11, 29, 55, 50, 25]
l=[10,20,30,40,50,60]

plt.hist(no,color='g',edgecolor='b',bottom=20,bins=l,rwidth=0.8)  # rwidth=0.8 to give space between bars


plt.xlabel("Python")
plt.ylabel("No")
plt.title('Vishwa') 
plt.show()

# %%
no=[19, 44, 31, 39, 47, 43, 18, 51, 45, 23, 18, 33, 10, 32, 58, 28, 30,
       42, 27, 16, 52, 59, 37, 53, 21, 49, 48, 11, 20, 56, 55, 46, 22, 53,
       51, 13, 18, 39, 17, 49, 32, 18, 29, 41, 26, 11, 29, 55, 50, 25]
l=[10,20,30,40,50,60]

plt.hist(no,color='g',edgecolor='b',bins=l,log="True") #to convert y axis to log table


plt.xlabel("Python")
plt.ylabel("No")
plt.title('Vishwa') 
plt.show()

# %%
no=[19, 44, 31, 39, 47, 43, 18, 51, 45, 23, 18, 33, 10, 32, 58, 28, 30,
       42, 27, 16, 52, 59, 37, 53, 21, 49, 48, 11, 20, 56, 55, 46, 22, 53,
       51, 13, 18, 39, 17, 49, 32, 18, 29, 41, 26, 11, 29, 55, 50, 25]
l=[10,20,30,40,50,60]

plt.hist(no,color='g',edgecolor='b',bins=l,label="python") #to give label to it


plt.xlabel("Python")
plt.ylabel("No")
plt.title('Vishwa') 
plt.legend()
plt.show()

# %%
no=[19, 44, 31, 39, 47, 43, 18, 51, 45, 23, 18, 33, 10, 32, 58, 28, 30,
       42, 27, 16, 52, 59, 37, 53, 21, 49, 48, 11, 20, 56, 55, 46, 22, 53,
       51, 13, 18, 39, 17, 49, 32, 18, 29, 41, 26, 11, 29, 55, 50, 25]
l=[10,20,30,40,50,60]

plt.hist(no,color='g',edgecolor='b',bins=l,label="python") 

plt.xlabel("Python")
plt.ylabel("No")
plt.title('Vishwa')

plt.axvline(45,color='r')
plt.legend()
plt.show()

# %%
no=[19, 44, 31, 39, 47, 43, 18, 51, 45, 23, 18, 33, 10, 32, 58, 28, 30,
       42, 27, 16, 52, 59, 37, 53, 21, 49, 48, 11, 20, 56, 55, 46, 22, 53,
       51, 13, 18, 39, 17, 49, 32, 18, 29, 41, 26, 11, 29, 55, 50, 25]
l=[10,20,30,40,50,60]

plt.hist(no,color='g',edgecolor='b',bins=l,label="python") 

plt.xlabel("Python")
plt.ylabel("No")
plt.title('Vishwa')

plt.axvline(45,color='r',label='line')#to give line
plt.legend()
plt.show()

# %%
no=[19, 44, 31, 39, 47, 43, 18, 51, 45, 23, 18, 33, 10, 32, 58, 28, 30,
       42, 27, 16, 52, 59, 37, 53, 21, 49, 48, 11, 20, 56, 55, 46, 22, 53,
       51, 13, 18, 39, 17, 49, 32, 18, 29, 41, 26, 11, 29, 55, 50, 25]
l=[10,20,30,40,50,60]

plt.hist(no,color='g',edgecolor='b',bins=l,label="python") 

plt.xlabel("Python")
plt.ylabel("No")
plt.title('Vishwa')

plt.axvline(45,color='r',label='line')
plt.legend()
plt.grid() #to show grid
plt.show()
